# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %% [markdown]
# #df.columns
#
# Use pandas usecols when you want to load specific columns into dataframe. When your input dataset contains a large number of columns, and you want to load a subset of those columns into a dataframe , then usecols will be very useful.
#
# Performance wise, it is  better because instead of loading an entire dataframe into memory and then deleting the not required columns, we can select the columns that we’ll need, while loading the dataset itself.
#
# https://honingds.com/blog/pandas-read_csv/
#
# #df = pd.read_excel(file_loc, index_col=None, na_values=['NA'], usecols = "A,C:AA")

# %%
verbatim = pd.read_csv("/Users/Vidya/Downloads/Fake News Poll Responses by Type and City_test.csv", header = 0, usecols=["Event Category"])
print(verbatim.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34321 entries, 0 to 34320
# Data columns (total 1 columns):
# Event Category    34321 non-null object
# dtypes: object(1)
# memory usage: 268.2+ KB
# None

# %%
verbatim.columns
# Out:
# Index([u'Event Category'], dtype='object')

# %%
#verbatim = verbatim.transpose()

# %%
verbatim[0:20]
# Out:
#                          Event Category
# 0        Yes, I have heard of fake news
# 1        Yes, I have heard of fake news
# 2        Yes, I have heard of fake news
# 3   Yes, I'm good at spotting fake news
# 4        Yes, I have heard of fake news
# 5                             Ignore it
# 6   Yes, I'm good at spotting fake news
# 7                             Ignore it
# 8   Yes, I'm good at spotting fake news
# 9        Yes, I have heard of fake news
# 10                            Ignore it
# 11  Yes, I'm good at spotting fake news
# 12       Yes, I have heard of fake news
# 13       Yes, I have heard of fake news
# 14       Yes, I have heard of fake news
# 15                            Ignore it
# 16    No, I'm bad at spotting fake news
# 17    No, I'm bad at spotting fake news
# 18       Yes, I have heard of fake news
# 19       Yes, I have heard of fake news

# %%
verbatim.rename(columns = {"Event Category": 'comments'}, inplace= True)

# %%
stopwords = set(STOPWORDS)

# %%
verbatim
# Out:
#                                                 comments
# 0                         Yes, I have heard of fake news
# 1                         Yes, I have heard of fake news
# 2                         Yes, I have heard of fake news
# 3                    Yes, I'm good at spotting fake news
# 4                         Yes, I have heard of fake news
# 5                                              Ignore it
# 6                    Yes, I'm good at spotting fake news
# 7                                              Ignore it
# 8                    Yes, I'm good at spotting fake news
# 9                         Yes, I have heard of fake news
# 10                                             Ignore it
# 11                   Yes, I'm good at spotting fake news
# 12                        Yes, I have heard of fake news
# 13                        Yes, I have heard of fake news
# 14                        Yes, I have heard of fake news
# ...

# %%
text = " ".join(review for review in verbatim.comments)

# %%
wordcloud = WordCloud(stopwords= stopwords,width = 1000, height = 500,max_font_size=150, max_words=100, background_color="white").generate(text)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig("/Users/Vidya/Projects/datasets/comments_wordcloud.png", format="png")
plt.show()

# %%
plt.savefig("/Users/Vidya/Projects/datasets/comments_wordcloud.png", format="png")
